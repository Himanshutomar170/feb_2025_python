# %%
a=10
b=20
c=a+b
print(c)     # shift + enter =shortcut key to run the cell
# Out:
# 30

# %% [markdown]
# **hi i am himanshu**
#
# **i am the best**

# %% [markdown]
# **testing git hub commands**
